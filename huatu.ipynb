# %%
from graphviz import Digraph
import graphviz
graphviz
# Out:
# <module 'graphviz' from '/Users/zeege/opt/anaconda3/lib/python3.9/site-packages/graphviz/__init__.py'>

# %%
edges = []

# %%
dot = Digraph()
with open('out/simple.txt') as file:
    node_num = 7

    for i in range(0, node_num):
        dot.node(str(i))

    data2 = file.readlines()
    for line in data2:
        dot.edge(str(line.split("\n")[0].split(',')[0]), str(line.split("\n")[0].split(',')[1]))
dot

# %%
dot

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ressult/sensitiviey.csv')
df.loc[df.dataset == 'word', 'size'] /= 72172
df.loc[df.dataset == 'enron', 'size'] /= 276143
df.loc[:, 'time'] /= 1000
df
# Out:
#      k      size      time dataset
# 0  100  0.209181     5.309    word
# 1   50  0.187372     6.414    word
# 2   25  0.170592    10.101    word
# 3   10  0.160117    20.256    word
# 4    0  0.147994  2156.447    word
# 5  100  0.127336   115.408   enron
# 6   50  0.122715   148.359   enron
# 7   25  0.116795   265.042   enron
# 8   10  0.112891   460.855   enron

# %%
fig, ax1 = plt.subplots()
sns.lineplot(x='k', y='size', hue='dataset', data=df, ax=ax1, marker='o')
ax1.set_ylabel('FAS(%)')
plt.savefig('out/sensitivity.pdf')
